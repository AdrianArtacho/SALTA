# %%
from segmentation import trainModel
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In [2], line 1
# ----> 1 from segmentation import trainModel
#
# File ~/Projects/AtlasOfSmoothSpaces/GestureLab/MpHandsRtclear/segmentation/trainModel.py:5
#       3 import numpy as np
#       4 import segmentation.segmentation as sg
# ----> 5 import utils.mediapipe as mp
#       7 ## Load libaries
#       9 from segmentation.trainModel import Model
#
# File ~/Projects/AtlasOfSmoothSpaces/GestureLab/MpHandsRtclear/utils/mediapipe.py:21
#      17 from utils import retrieveVideo as rV
#      20 import segmentation.segmentation as sg
# ---> 21 from segmentation.trainModel import Model
#      22 from db.gyro import Gyro
#      23 from db.pose import MediapipePose
#
# ...
