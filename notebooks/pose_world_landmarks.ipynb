# %%
import sys, os
cwd = os.getcwd()
print(cwd)
sys.path.insert(0, os.path.join(cwd, '..'))
# Out:
# /Users/artacho/Documents/Max 8/Projects/[Atlas]/mp_hands_rt/notebooks

# %%
from segmentation.trainModel import Training

# %%
tr = Training()

# %% [markdown]
# ### Try to retrieve a youtube clip

# %%
rawMotionBankCSVPath = "../data/gesturetest.csv"
df_filtered, parseddict = tr.getFilteredDataFrame(
    rawMotionBankCSVPath=rawMotionBankCSVPath,
    landmarkFileName="testLMFN.csv",
    fromRoot=False,
    saveOutputToCSV=True)
# Out:
# You chose to parse the annotations corresponding to 'video1':
# {'name': 'https://youtu.be/gjCHOGdPIR8', 'by': 'Adrián Artacho', 'from': 0.0, 'till': 4.0}
# Annotations earlier than 0.0 and later than 4.0 will be removed.
# All annotation times will be offset by 0.0 seconds.
# You chose to process annotations by Adrián Artacho.
# ('annotation1', {'name': 'hello', 'by': 'Adrián Artacho', 'from': 0.0, 'till': 1.9500000476837158})
# ('annotation2', {'name': 'bye', 'by': 'Adrián Artacho', 'from': 1.9500000476837158, 'till': 1.9500000476837158})
# ['mouth_left', 'left_elbow']
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# Ignoring empty frame.

# %% [markdown]
# ### Step by step

# %%
hardcodedargs = {'rawMotionBankCSVPath': 'data/gesturetest.csv', 'landmarkFileName': '2022-12-16_21-38', 'fromCache': False, 'fromRoot': True, 'saveOutputToCSV': True}
landmarkFileName = 'exampleblaa'
rawMotionBankCSVPath = '../data/gesturetest.csv'

# %% [markdown]
# ```python
# #Retrieves the youtube link from the rawMotionBankCSVPath and extracts the landmarks
# getFilteredDataFrame(self, rawMotionBankCSVPath, landmarkFileName, fromCache=False, fromRoot=False, saveOutputToCSV=True)
# ```

# %%
df, parse_anno = tr.getFilteredDataFrame(rawMotionBankCSVPath, landmarkFileName, fromCache=True, fromRoot=False, saveOutputToCSV=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/6_/bgwtqg5s71sgqt20w2d1q77w0000gn/T/ipykernel_9771/964271198.py in <module>
# ----> 1 df, parse_anno = tr.getFilteredDataFrame(rawMotionBankCSVPath, landmarkFileName, fromCache=True, fromRoot=False, saveOutputToCSV=True)
#
# ~/Documents/Max 8/Projects/[Atlas]/mp_hands_rt/notebooks/../segmentation/trainModel.py in getFilteredDataFrame(self, rawMotionBankCSVPath, landmarkFileName, fromCache, fromRoot, saveOutputToCSV)
#      79         """
#      80         # retrieve URL of youtube video and annotation dict from raw motion bank path
# ---> 81         url, parseddict = pa.parseCSV(rawMotionBankCSVPath)
#      82         # convert url into cv2 readable input
#      83         videoURL = rV.retrieveVideo(url=url)
#
# ...

# %%
rawMotionBankCSVPath = "../data/gesturetest.csv"

# %%
df_filtered, parseddict = tr.getFilteredDataFrame(
    rawMotionBankCSVPath=rawMotionBankCSVPath,
    landmarkFileName="testLMFN.csv",
    fromRoot=False,
    saveOutputToCSV=True)
# Out:
# You chose to parse the annotations corresponding to 'video1':
# {'name': 'https://youtu.be/gjCHOGdPIR8', 'by': 'Adrián Artacho', 'from': 0.0, 'till': 4.0}
# Annotations earlier than 0.0 and later than 4.0 will be removed.
# All annotation times will be offset by 0.0 seconds.
# You chose to process annotations by Adrián Artacho.
# ('annotation1', {'name': 'hello', 'by': 'Adrián Artacho', 'from': 0.0, 'till': 1.9500000476837158})
# ('annotation2', {'name': 'bye', 'by': 'Adrián Artacho', 'from': 1.9500000476837158, 'till': 1.9500000476837158})
# ['right_eye', 'mouth_right']
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# Ignoring empty frame.
