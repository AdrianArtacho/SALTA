# %%
import pafy

# %%
url = "https://www.youtube.com/watch?v=6zQkbTzN8yY"
video = pafy.new(url,ydl_opts={'nocheckcertificate': True})

# %%
best  = video.getbest()

# %%
video
# Out:
# Title: 2022 09 23 220627
# Author: Smooth Space
# ID: 6zQkbTzN8yY
# Duration: 00:08:15
# Rating: None
# Views: 2
# Thumbnail: http://i.ytimg.com/vi/6zQkbTzN8yY/default.jpg

# %%
def retrieveVideo(url = "https://www.youtube.com/watch?v=6zQkbTzN8yY"):
  video = pafy.new(url)
  best  = video.getbest()
  try:
    return best.url
  except Exception as e:
    raise e
